# %%
import numpy as np
import pandas as pd
import torch
from load_forecasting.data import *

# %%
df = pd.read_excel(r'附件3：训练数据集\训练数据项目A历史数据_2025-04-01_2025-10-31.xlsx')
print(feature_frame(df))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 df = pd.read_excel(r'附件3：训练数据集\训练数据项目A历史数据_2025-04-01_2025-10-31.xlsx')
# ----> 2 print(feature_frame(df))
#
# File i:\2-项目\0-竞赛\AI 节能\load_forecasting\data.py:75, in feature_frame(df)
#      73 """组合数值传感器变量和周期时间特征。"""
#      74 numeric = df.select_dtypes(include=[np.number]).copy()
# ---> 75 time_features = _time_features(df[TIME_COLUMN])
#      76 features = pd.concat([time_features,numeric], axis=1)
#      77 return features.astype(np.float32), list(features.columns)
#
# File i:\2-项目\0-竞赛\AI 节能\load_forecasting\data.py:56, in _time_features(timestamps)
#      55 def _time_features(timestamps: pd.Series) -> pd.DataFrame:
# ---> 56     hour = timestamps.dt.hour.to_numpy()
#      57     weekday = timestamps.dt.dayofweek.to_numpy()
#      58     month = timestamps.dt.month.to_numpy()
#
# ...
